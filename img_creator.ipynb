# %%
import matplotlib.pyplot as plt

from file_utils import load_list_from_file

# %%
errors1 = load_list_from_file("data/errors1.txt", float)
plt.plot(errors1)
plt.grid()
plt.ylabel('Error value 1')
plt.savefig("img/error1.png")
plt.show()

# %%
errors2 = load_list_from_file("data/errors2.txt", float)
plt.plot(errors2)
plt.grid()
plt.ylabel('Error value 2')
plt.savefig("img/error2.png")
plt.show()

# %%
its = load_list_from_file("data/its.txt", int)
opt_its = load_list_from_file("data/opt_its.txt", int)
# bound = len(its)
bound = 350
x = list(range(len(its[:bound])))

plt.plot(x, sorted(its)[:bound], "r")
# plt.plot(x, its[:bound], "r")
plt.plot(x, sorted(opt_its)[:bound], "b")
# plt.plot(x, opt_its[:bound], "b")

plt.show()

# %%
diff = load_list_from_file("data/diff.txt", int)
diff = list(map(abs, diff))
plt.plot(sorted(diff)[:300], "g")

plt.show()
